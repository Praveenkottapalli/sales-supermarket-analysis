# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv("C://Users/Praveen/Desktop/Codebasics/pyhton/sales (1).csv")
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.head(10)       # to fetch  top 10 records from the table
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sales.tail(10)     # to fetch  bottom 10 records from the table
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 990   Clothing     25         4    100    Cash       5
# 991  Furniture     96         7    672    Card       3
# ...

# %%
sales.info()     # to know about the datatype  of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Invoice ID  1000 non-null   int64
#  1   Date        1000 non-null   object
#  2   Time        1000 non-null   object
#  3   Gender      1000 non-null   object
#  4   Location    1000 non-null   object
#  5   City        1000 non-null   object
#  6   Member      1000 non-null   object
#  7   Category    1000 non-null   object
#  8   Price       1000 non-null   int64
#  9   Quantity    1000 non-null   int64
#  10  Total       1000 non-null   int64
#  11  Payment     1000 non-null   object
#  12  Rating      1000 non-null   int64
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %%
sales.describe()
# Out:
#          Invoice ID        Price     Quantity        Total       Rating
# count  1.000000e+03  1000.000000  1000.000000  1000.000000  1000.000000
# mean   4.944931e+08    51.112000     4.059000   207.788000     2.972000
# std    2.870685e+08    28.912443     2.027716   165.626167     1.428025
# min    6.614050e+05     1.000000     1.000000     1.000000     1.000000
# 25%    2.508726e+08    27.000000     2.000000    72.000000     2.000000
# 50%    4.781491e+08    51.000000     4.000000   174.000000     3.000000
# 75%    7.459453e+08    76.250000     6.000000   304.500000     4.000000
# max    9.996658e+08   100.000000     7.000000   693.000000     5.000000

# %%
sales.isnull().sum() # to check is there any null values are there
# Out:
# Invoice ID    0
# Date          0
# Time          0
# Gender        0
# Location      0
# City          0
# Member        0
# Category      0
# Price         0
# Quantity      0
# Total         0
# Payment       0
# Rating        0
# dtype: int64

# %%
sales[["Location"]]  # to fetch the specific column
# Out:
#         Location
# 0     Brookfield
# 1    Water tower
# 2    Water tower
# 3      Park lane
# 4      Park lane
# ..           ...
# 995    Park lane
# 996  Water tower
# 997   Brookfield
# 998   Brookfield
# 999  Water tower
#
# [1000 rows x 1 columns]

# %%
sales["Location"].unique()   # to know about the how many  distinct location are there
# Out:
# array(['Brookfield', 'Water tower', 'Park lane'], dtype=object)

# %%
sales.iloc[120]  # to know about the specific row
# Out:
# Invoice ID    127206426
# Date          1/20/2018
# Time              18:17
# Gender             Male
# Location      Park lane
# City             Dallas
# Member               No
# Category       Clothing
# Price                70
# Quantity              1
# Total                70
# Payment            Card
# Rating                1
# Name: 120, dtype: object

# %%
sales[100:150]  # to fetch the records  from 100 to 150
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 100   515862366  2/12/2018  10:57  Female    Park lane   Dallas     No
# 101    42787009  3/28/2018  11:25  Female    Park lane   Dallas    Yes
# 102   780195692  2/20/2018  12:42  Female    Park lane   Dallas     No
# 103   881639873  2/27/2018  15:05    Male    Park lane   Dallas    Yes
# 104   443388850   2/5/2018  16:31    Male   Brookfield  NewYork    Yes
# 105   635503529  3/24/2018  15:17    Male  Water tower  Chicago     No
# 106   774895188   2/7/2018  20:29  Female   Brookfield  NewYork    Yes
# 107   194154086  2/11/2018  16:28  Female   Brookfield  NewYork    Yes
# 108   191782944  1/20/2018  19:28  Female   Brookfield  NewYork    Yes
# 109   949506131   2/8/2018  10:43    Male   Brookfield  NewYork    Yes
# 110   866328026   1/3/2018  14:41    Male  Water tower  Chicago    Yes
# 111    43708341   3/5/2018  15:54    Male    Park lane   Dallas    Yes
# ...

# %%
sales[sales['Gender']=='Male']   # to sort the results based on Gender
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['Gender']=='Male'].count()  # to count the how many males are there
# Out:
# Invoice ID    499
# Date          499
# Time          499
# Gender        499
# Location      499
# City          499
# Member        499
# Category      499
# Price         499
# Quantity      499
# Total         499
# Payment       499
# Rating        499
# dtype: int64

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.query('Gender=="Male" & Payment=="Cash"')  # query is used to use more than one condition
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# 12    149894432  1/12/2018  11:12   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 975   464762614   3/3/2018  10:38   Male  Water tower  Chicago     No
# 976   497734676   2/9/2018  14:14   Male    Park lane   Dallas     No
# 985   266635768  1/29/2018  14:30   Male  Water tower  Chicago    Yes
# 990   752407865  1/15/2018  10:01   Male  Water tower  Chicago    Yes
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales.min()['Total']
# Out:
# 1

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales.mean()['Total']
# Out:
# C:\Users\Praveen\AppData\Local\Temp\ipykernel_20872\1945902060.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sales.mean()['Total']
# 207.788

# %% [markdown]
# overall sales performance

# %%
Total_revenue = sales['Total'].sum()
print(f"Total Revenue: {total_revenue}")
# Out:
# Total Revenue: 207788

# %%
Total_transactions = sales['Invoice ID'].nunique()
print(f"Total Transactions: {total_transactions}")
# Out:
# Total Transactions: 1000

# %%
total_quantity = sales['Quantity'].sum()
print(f"Total Quantity Sold: {total_quantity}")
# Out:
# Total Quantity Sold: 4059

# %%
sales.groupby("Gender").sum("Total")
# Out:
#           Invoice ID  Price  Quantity   Total  Rating
# Gender
# Female  253138028847  25474      2069  106452    1517
# Male    241355024494  25638      1990  101336    1455

# %%
sales.groupby("Date").sum()['Total']
# Out:
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %%
location_list=sales.groupby('Location')

# %%
location = [x for x,y in location_list ]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(location,sales.groupby('Location').sum()['Total'],color='b')
plt.grid()
plt.title("sales by location",size=30,color='k')
plt.xlabel("location",size=20,color='k')
plt.ylabel("Total",size=20,color='k')
# Out:
# Text(0, 0.5, 'Total')

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
plt.show()

# %%
unstack_sales=sales.groupby(['Gender' , 'Location']).count()['City'].unstack(level=0)   # unstack used for row and column sequence
unstack_sales
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
unstack_sales.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %% [markdown]
# # which branch as more members vs which branch less members

# %%
member_sales=sales.groupby(['Location' , 'Member']).count()['Date']
member_sales #which branch as more members vs which branch less members
# Out:
# Location     Member
# Brookfield   No        173
#              Yes       167
# Park lane    No        167
#              Yes       165
# Water tower  No        159
#              Yes       169
# Name: Date, dtype: int64

# %%
unstack_member_sales=member_sales.unstack()   # unstack is used when more than one index here member and location
unstack_member_sales                           # if only member is there unstack doesn't work
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
unstack_member_sales.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
rating=sales.groupby('Location').mean()['Rating']
rating
# Out:
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
type(rating)
# Out:
# pandas.core.series.Series

# %%
rating.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %% [markdown]
# which city has more female shopping

# %%
female_shopper=sales.groupby(["Gender","City"]).count()['Location']
female_shopping
# Out:
# City     Gender
# Chicago  Female    143
#          Male      185
# Dallas   Female    179
#          Male      153
# NewYork  Female    179
#          Male      161
# Name: Location, dtype: int64

# %%
female_shopper.unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# who spends more men or women

# %%
spends=sales.groupby('Gender').sum()['Total']
spends
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %% [markdown]
# which product sells more

# %%
customer=sales.groupby('Member').sum()['Total']
customer

# %%
customer.plot(kind='bar')
plt.grid()

# %%
category=sales.groupby('Category').sum()['Total']
category

# %%
plt.figure(figsize=(10,5))
category.plot(kind='line')
plt.grid()
plt.ylabel('Total',size=15)
plt.title('Category trend by total',size=25)

# %% [markdown]
# which product line is popular among men or women

# %%
category_popular=sales.groupby(['Gender','Category']).count()['Total']
trend=category_popular.unstack(level=0)
trend

# %%
trend.plot(kind='bar')
plt.ylabel('Total')
plt.title("Category and gender trend by total")
plt.show()

# %% [markdown]
# which product line sells more

# %%
sells=sales.groupby('Category').count()['Time']
sells

# %%
sells.plot(kind='bar')
plt.grid()

# %% [markdown]
# time intelligence

# %%
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
type('Date')   # need to convert into datetime format
# Out:
# str

# %%
to_datetime=pd.to_datetime(sales['Date'])
to_datetime
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
type(to_datetime)
# Out:
# pandas.core.series.Series

# %%
day=pd.to_datetime(sales['Date']).dt.day
day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
month=pd.to_datetime(sales['Date']).dt.day
month
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
year=pd.to_datetime(sales['Date']).dt.year
year
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 995    2018
# 996    2018
# 997    2018
# 998    2018
# 999    2018
# Name: Date, Length: 1000, dtype: int64

# %%
day.unique()
# Out:
# array([25, 19, 22, 18,  9,  4,  8, 24, 26, 15, 12, 21,  6,  7, 23, 20,  3,
#        14, 28, 30,  2,  5, 16, 29, 17, 11, 27, 10, 13,  1, 31],
#       dtype=int64)

# %%
month.unique()
# Out:
# array([25, 19, 22, 18,  9,  4,  8, 24, 26, 15, 12, 21,  6,  7, 23, 20,  3,
#        14, 28, 30,  2,  5, 16, 29, 17, 11, 27, 10, 13,  1, 31],
#       dtype=int64)

# %%
year.unique()
# Out:
# array([2018], dtype=int64)

# %%
sales['day']=pd.to_datetime(sales['Date']).dt.day        # adding a new column day,month and year after converting into day,month,year
sales['month']=pd.to_datetime(sales['Date']).dt.month
sales['year']=pd.to_datetime(sales['Date']).dt.year

# %% [markdown]
# what days of month make most sales

# %%
day_sales=sales.groupby('day').sum()['Total']
day_sales
# Out:
# day
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(10,5))
day_sales.plot(kind='line',marker='o')
plt.title("Sales by day",size=20)
# Out:
# Text(0.5, 1.0, 'Sales by day')

# %%
plt.figure(figsize=(10,5))
month_sales.plot(kind='bar')
plt.title("Sales by month",size=20)
# Out:
# Text(0.5, 1.0, 'Sales by month')

# %%
plt.figure(figsize=(10,5))
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(day_sales,marker='o')
axes[0].set_title("Sales by day")
month_sales.plot(kind='bar',ax=axes[1],color='g')
axes[1].set_title("Sales by month")
plt.show()

# %% [markdown]
# what hour make the most sales

# %%
sales['Hour']=pd.to_datetime(sales['Time']).dt.hour
sales['Hour']
# Out:
# 0      16
# 1      16
# 2      13
# 3      13
# 4      15
#        ..
# 995    11
# 996    17
# 997    11
# 998    15
# 999    10
# Name: Hour, Length: 1000, dtype: int64

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  day  month  year  Hour
# ...

# %%
hour_sales=sales.groupby('Hour').sum()['Total']
hour_sales
# Out:
# Hour
# 10    20235
# 11    20274
# 12    17396
# 13    22146
# 14    15084
# 15    23717
# 16    14708
# 17    14443
# 18    20528
# 19    24221
# 20    15036
# Name: Total, dtype: int64

# %%
hour_sales.plot(kind='bar')
plt.title("hour sales by total",size=20)
# Out:
# Text(0.5, 1.0, 'hour sales by total')

# %%
hour_sales.plot(kind='line',marker='o')
# Out:
# <AxesSubplot:xlabel='Hour'>

# %% [markdown]
# what times do people make more payments vs what time people make more cash payments

# %%
time_payments=sales.groupby(['Hour','Payment']).count()['Total']
time_payments.unstack()
# Out:
# Payment  Card  Cash  Gpay
# Hour
# 10         29    35    37
# 11         25    36    29
# 12         27    27    35
# 13         35    37    31
# 14         22    32    29
# 15         37    38    27
# 16         23    31    23
# 17         28    21    25
# 18         25    29    39
# 19         34    32    47
# 20         26    26    23

# %%
time_payments.unstack().plot(kind='bar',legend=False)
plt.show()

# %%
sales.columns
# Out:
# Index(['Invoice ID', 'Date', 'Time', 'Gender', 'Location', 'City', 'Member',
#        'Category', 'Price', 'Quantity', 'Total', 'Payment', 'Rating', 'day',
#        'month', 'year', 'Hour'],
#       dtype='object')

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604 2018-01-25  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167 2018-03-19  16:48  Female  Water tower  Chicago    Yes
# 2     411909258 2018-02-25  13:33    Male  Water tower  Chicago     No
# 3     487313402 2018-01-22  13:38  Female    Park lane   Dallas    Yes
# 4     197763430 2018-02-18  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599 2018-03-26  11:19    Male    Park lane   Dallas     No
# 996   556589713 2018-02-20  17:17    Male  Water tower  Chicago    Yes
# 997    82324424 2018-02-06  11:44    Male   Brookfield  NewYork     No
# 998   783661702 2018-01-29  15:44  Female   Brookfield  NewYork     No
# 999   759171975 2018-01-31  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  day  month  year  Hour
# ...

# %%
sales['Date'] = pd.to_datetime(sales['Date'],in)
sales['Date']
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604 2018-01-25  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167 2018-03-19  16:48  Female  Water tower  Chicago    Yes
# 2     411909258 2018-02-25  13:33    Male  Water tower  Chicago     No
# 3     487313402 2018-01-22  13:38  Female    Park lane   Dallas    Yes
# 4     197763430 2018-02-18  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599 2018-03-26  11:19    Male    Park lane   Dallas     No
# 996   556589713 2018-02-20  17:17    Male  Water tower  Chicago    Yes
# 997    82324424 2018-02-06  11:44    Male   Brookfield  NewYork     No
# 998   783661702 2018-01-29  15:44  Female   Brookfield  NewYork     No
# 999   759171975 2018-01-31  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  day  month  year  Hour
# ...

# %%
f=sales['Date']
f
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
type(f)
# Out:
# pandas.core.series.Series

# %%
city_sales = sales.groupby('City')['Total'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
city_sales.plot(kind='bar', color='skyblue')
plt.xlabel('City')
plt.ylabel('Total Sales')
plt.title('Sales by City')
plt.xticks(rotation=45)
plt.show()

# %%
gender_sales = sales.groupby('Gender')['Total'].sum()

plt.figure(figsize=(5, 5))
gender_sales.plot(kind='pie', autopct='%1.1f%%', colors=['y', 'skyblue'])
plt.title('Sales Distribution by Gender')
plt.ylabel('')
plt.show()

# %% [markdown]
# Revenue & Trends: What months/hours bring in the most sales?
# Location Impact: Which cities contribute most to sales?
# Product Performance: What categories sell best?
# Customer Insights: Who buys more—men, women, members?
# Payment Preferences: What’s the most used payment method?
# Ratings & Sales: Do high ratings mean higher sales?
